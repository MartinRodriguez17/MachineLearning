# %%
jugadores= ['messi', 'ronaldo', 'neymar']
jugadores.extend(['rivaldo'])
print (jugadores)
# Out:
# ['messi', 'ronaldo', 'neymar', 'rivaldo']

# %%
gays = ['adrian', 'anderson']
novios = ['maiccol', 'alan']

asquito = gays + novios

print (asquito)
# Out:
# ['adrian', 'anderson', 'maiccol', 'alan']
